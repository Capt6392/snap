# %%
class Node:
  def __init__(self,value):
    self.data=value
    self.next=None

# %%
class linkedlist:
  def __init__(self):
    #empty linked list
    self.n=0
    self.head= None

  def __len__(self):
    return self.n

  def insert_head(self,value):
    #creating a new node
    new_node=Node(value)
    # address of the head is stored in the new node
    new_node.next=self.head
    # making the new node the head
    self.head=new_node
    #incrementing the length of the linked list
    self.n=self.n+1

  def __str__(self):
    result=''
    curr=self.head
    while curr !=None:
      result=result+str(curr.data)+'-->'
      curr=curr.next
    return result[:-3]

  def append(self,value):
    #if empty linkedlist
    if self.head==None:
      self.head=Node(value)
      self.n=self.n+1 # you can use use return to stop th efurther execution
    else:
      new_node=Node(value)
      curr=self.head
      while curr.next!=None:
        curr=curr.next
    # yor are at the end node
      curr.next=new_node

      self.n=self.n+1
  def insert_after(self, after,value):
    curr= self.head
    new_node=Node(value)
    while curr!=None:
      if curr.data==after:
        break
      curr=curr.next
    if curr!=None:
      new_node.next=curr.next
      curr.next=new_node
    else:
      return "value not found"

  def clear(self):
    #empty the list
    self.head=None
    self.n=0

  def del_head(self):
    if self.head==None:
      return "already empty"
    #deleting the starting node
    else:
      self.head=self.head.next
      self.n=self.n-1
  def pop(self):
    if self.head==None:
      #if already empty
      return "empty linked list "

    curr=self.head
    if curr.next==None:
      #if only one item is there
       return self.del_head()

    while curr.next.next!=None:
      curr=curr.next
    return curr.data
    curr.next=None

    self.n=self.n-1
  def remove(self, value):
    if self.head==NOne:
      return "emty ll"
    if self.head.data==value:
      return self.del_head()
    curr = self.head
    while curr.next!=None:
      if curr.next.data==value:
        break
      curr=curr.next
    if curr.next==None:
      return "item not found "
    else:
      curr.next=curr.next.next
      self.n=self.n-1
  def search(self, value):
    count=0
    curr=self.head
    while curr.next!=None:
      if curr.data==value:
        return count
      curr=curr.next
      count=count+1
    return "item not found "
  def __getitem__(self, index):
    curr=self.head
    count=0
    while curr!=None:
      if count==index:
        return curr.data
      curr=curr.next
      count=count+1
    return " item not found in the range "
  def replace_max(self, value):
    temp=self.head
    max=temp
    while temp!= None:
      if temp.data> max.data:
        max=temp
      temp= temp.next
    max.data=value
  def max(self):
    temp=self.head
    m=temp.data
    while temp!=None:
      if temp.data>m:
        m = temp.data
      temp=temp.next
    return m
  def min(self):
    temp= self.head
    m= temp.data
    while temp!=None:
      if temp.data<m:
        m= temp.data
      temp= temp.next
    return m
  def sum(self):
    s=0
    curr= self.head
    while curr!= None:
      s=s+curr.data
    curr= curr.next
    return s
  def odd_sum(self):
    count=0
    temp=self.head
    sum=0
    while temp!=None:
      if count%2!=0:
        sum=temp.data+sum
      temp=temp.next
      count=count+1
  def change_sen(self):
    temp = self.head
    while temp != None:
      if temp.data=='*' or temp.data=='/':
        temp.data=' '
        if temp.next.data=='*' or temp.next.data=='/':
          temp.next.next.data=temp.next.next.data.upper()
          temp.next=temp.next.next
      temp=temp.next
  def show(self):
    temp=self.head
    result=''
    while temp!=None:
      result=result+str(temp.data)
      temp=temp.next
    return result
  def reverse(self):
    curr= self.head
    pre_node= None
    while curr!=None:
      next_node=curr.next
      curr.next=pre_node
      curr=next_node
    self.head=pre_node

# %%
l2=linkedlist()

# %%
l2.insert_head('T')

# %%
print(l2)
l2.insert_head('e')
# Out:
# T

# %%
l2.insert_head('h')
l2.insert_head('i')

# %%
print(l2)
# Out:
# i-->h-->T

# %%
l2.show()
# Out:
# 'ihT'

# %%
l1.reverse()

# %%
print(l1)

# %%
len(l1)
# Out:
# 4

# %%
l1.append(78)

# %%
print(l1)
# Out:
# 239-->2-->3-->23-->78-->1-->56-->78

# %%
l1.insert_after(23,456)

# %%
print(l1)
# Out:
# 239-->2-->3-->23-->456-->78-->1-->56-->78

# %%
l1.pop()
# Out:
# 56

# %%
len(l1)
# Out:
# 7

# %%
class Solution:
  def peak( self, arr , n):
    temp=0
    for i in arr:
      if temp<i:
        temp=i
      else:
        continue
    return temp
  def getminmax(self, arr, n ):
    temp=0
    res=[]
    sub=1
    for i in arr:
       if temp<i:
        temp=i
        min=i
        for j in arr:
          if temp< j :
            temp=j
    print(temp)

# %%
c1=Solution()

# %%
arr=[12,34,45,7,888,90]
c1.getminmax(arr, 6)
# Out:
# 888 90
